# %% [markdown]
# ### Import Libraries

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\rafa\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import tensorflow as tf 
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import nltk
from nltk.corpus import stopwords
import json
# Out:
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.head()
# Out:
#                                             sentence  label
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  1000 non-null   object
#  1   label     1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
df['sentence'] = df['sentence'].str.lower()

df.head()
# Out:
#                                             sentence  label
# 0                                wow... loved place.      1
# 1                                        crust good.      0
# 2                               tasty texture nasty.      0
# 3  stopped late may bank holiday rick steve recom...      1
# 4                       selection menu great prices.      1

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rafa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_word = set(stopwords.words('english'))

df['sentence'] = df['sentence'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop_word)]))

df.head()
# Out:
#                                             sentence  label
# 0                                wow... loved place.      1
# 1                                        crust good.      0
# 2                               tasty texture nasty.      0
# 3  stopped late may bank holiday rick steve recom...      1
# 4                       selection menu great prices.      1

# %%
sentence = df['sentence'].values
label = df['label'].values

# %%
sentence_train, sentence_test, label_train, label_test = train_test_split(sentence, label, test_size=0.2, shuffle=False)

print('Training dataset:\n', sentence_train.shape, label_train.shape)
print('\nTest dataset:\n', sentence_test.shape, label_test.shape)
# Out:
# Training dataset:
#  (800,) (800,)
#
# Test dataset:
#  (200,) (200,)

# %%
filt = '!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ' # Untuk menghilangkan symbols

tokenizer = Tokenizer(num_words=2000, oov_token="<OOV>", filters=filt)

tokenizer.fit_on_texts(sentence_train)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\]'
# <>:1: SyntaxWarning: invalid escape sequence '\]'
# C:\Users\Rafa\AppData\Local\Temp\ipykernel_5996\1414076117.py:1: SyntaxWarning: invalid escape sequence '\]'
#   filt = '!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ' # Untuk menghilangkan symbols

# %%
word_index = tokenizer.word_index
print(len(word_index))
# Out:
# 1720

# %%
# Menyimpan word_index kedalam sebuah file json

with open('word_index.json', 'w') as fp:
    json.dump(word_index, fp)

# %%
train_sekuens = tokenizer.texts_to_sequences(sentence_train)
test_sekuens = tokenizer.texts_to_sequences(sentence_test)


train_padded = pad_sequences(train_sekuens, 
                             maxlen=20,
                             padding='post',
                             truncating='post')
test_padded = pad_sequences(test_sekuens,
                            maxlen=20,
                            padding='post',
                            truncating='post')

# %%
train_padded.shape
# Out:
# (800, 20)

# %%
test_padded.shape
# Out:
# (200, 20)

# %%
model = tf.keras.Sequential([
    Embedding(2000, 20, input_length=20),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(train_padded, label_train, 
                    epochs=num_epochs, 
                    validation_data=(test_padded, label_test),
                    verbose=1)
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5612 - loss: 0.6873 - val_accuracy: 0.2400 - val_loss: 0.7561
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5650 - loss: 0.6807 - val_accuracy: 0.2400 - val_loss: 0.7648
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5650 - loss: 0.6751 - val_accuracy: 0.2400 - val_loss: 0.7586
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6025 - loss: 0.6538 - val_accuracy: 0.8400 - val_loss: 0.6676
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7100 - loss: 0.6170 - val_accuracy: 0.4500 - val_loss: 0.6872
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8188 - loss: 0.5223 - val_accuracy: 0.8200 - val_loss: 0.5730
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.3906 - val_accuracy: 0.8400 - val_loss: 0.4921
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9162 - loss: 0.2856 - val_accuracy: 0.4800 - val_loss: 0.8255
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9262 - loss: 0.2146 - val_accuracy: 0.7050 - val_loss: 0.5901
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9538 - loss: 0.1511 - val_accuracy: 0.8200 - val_loss: 0.4197
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9663 - loss: 0.1282 - val_accuracy: 0.7850 - val_loss: 0.5167
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9737 - loss: 0.1011 - val_accuracy: 0.6900 - val_loss: 0.6755
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.0886 - val_accuracy: 0.7650 - val_loss: 0.5915
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9775 - loss: 0.0776 - val_accuracy: 0.7800 - val_loss: 0.5904
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9750 - loss: 0.0768 - val_accuracy: 0.7150 - val_loss: 0.7247
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9850 - loss: 0.0549 - val_accuracy: 0.7750 - val_loss: 0.6112
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9750 - loss: 0.0642 - val_accuracy: 0.8050 - val_loss: 0.5325
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0534 - val_accuracy: 0.7900 - val_loss: 0.6409
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0345 - val_accuracy: 0.7850 - val_loss: 0.6274
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0354 - val_accuracy: 0.6400 - val_loss: 0.9558
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0334 - val_accuracy: 0.7650 - val_loss: 0.7126
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0364 - val_accuracy: 0.7600 - val_loss: 0.7243
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9925 - loss: 0.0346 - val_accuracy: 0.7950 - val_loss: 0.6502
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.0459 - val_accuracy: 0.7950 - val_loss: 0.6363
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0252 - val_accuracy: 0.7600 - val_loss: 0.7845
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9950 - loss: 0.0213 - val_accuracy: 0.7750 - val_loss: 0.7387
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0180 - val_accuracy: 0.7550 - val_loss: 0.8261
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9950 - loss: 0.0192 - val_accuracy: 0.7650 - val_loss: 0.7839
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9937 - loss: 0.0203 - val_accuracy: 0.7750 - val_loss: 0.7580
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9975 - loss: 0.0139 - val_accuracy: 0.7550 - val_loss: 0.8344

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, num_epochs), history.history["accuracy"], label="training")
plt.plot(np.arange(0, num_epochs), history.history["val_accuracy"], label="validation")
plt.title("Plot Akurasi")
plt.xlabel("Epoch")
plt.ylabel("Akurasi")
plt.legend()
plt.savefig('images/plot_acc.png')
plt.show()

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !pip install tensorflowjs
# Out:
# Requirement already satisfied: tensorflowjs in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (3.18.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflowjs) (2.20.0)
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\rafa\appdata\roaming\python\python312\site-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: packaging~=20.9 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflowjs) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from packaging~=20.9->tensorflowjs) (3.2.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (80.10.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.13.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.3.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.1.0->tensorflowjs) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.1.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.1.0->tensorflowjs) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.1.0->tensorflowjs) (3.10.1)
# Requirement already satisfied: pillow in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.1.0->tensorflowjs) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: rich in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.10.0->tensorflow<3,>=2.1.0->tensorflowjs) (14.2.0)
# Requirement already satisfied: namex in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.10.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.1.0)
# Requirement already satisfied: optree in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.10.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.10.0->tensorflow<3,>=2.1.0->tensorflowjs) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rafa\appdata\roaming\python\python312\site-packages (from rich->keras>=3.10.0->tensorflow<3,>=2.1.0->tensorflowjs) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rafa\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# mengubah model.h5 kedalam bentuk json
# !tensorflowjs_converter --input_format=keras model.h5 tfjs_model
# Out:
# 2026-02-16 21:53:48.337318: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# 2026-02-16 21:53:55.118760: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\read_weights.py:28: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.uint8, np.uint16, np.object, np.bool]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Rafa\AppData\Local\Programs\Python\Python312\Scripts\tensorflowjs_converter.exe\__main__.py", line 2, in <module>
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\__init__.py", line 21, in <module>
#     from tensorflowjs import converters
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\converters\__init__.py", line 21, in <module>
#     from tensorflowjs.converters.converter import convert
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\converters\converter.py", line 35, in <module>
#     from tensorflowjs.converters import keras_h5_conversion as conversion
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\converters\keras_h5_conversion.py", line 33, in <module>
#     from tensorflowjs import write_weights  # pylint: disable=import-error
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\write_weights.py", line 25, in <module>
#     from tensorflowjs import read_weights
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflowjs\read_weights.py", line 28, in <module>
#     np.uint8, np.uint16, np.object, np.bool]
#                          ^^^^^^^^^
#   File "c:\Users\Rafa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\__init__.py", line 791, in __getattr__
#     raise AttributeError(__former_attrs__[attr], name=None)
# AttributeError: module 'numpy' has no attribute 'object'.
# `np.object` was a deprecated alias for the builtin `object`. To avoid this error in existing code, use `object` by itself. Doing this will not modify any behavior and is safe.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
